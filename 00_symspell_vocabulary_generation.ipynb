# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

sys.path.insert(0, '/content/drive/MyDrive/hack_2023_11')

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np
from nltk import ngrams
import os
import pandas as pd
import re
from tqdm import tqdm
tqdm.pandas()

from spelling_checker.sym_spell_servicer import SymSpellRouterServicer

spell_checker = SymSpellRouterServicer()

# %%
WORD_PATTERN = re.compile(r"[a-zа-яйё!&'._|\-+:]+")
WORD_STRIP = "&'_|-:"
VALID_CHARS = "!&'._|-+:"

# %% [markdown]
# # Load data

# %%
video_meta = pd.read_parquet("/content/drive/MyDrive/hack_2023_11/data/videos.parquet")

queries_1 = pd.read_parquet("/content/drive/MyDrive/hack_2023_11/data/automarkup.parquet")
queries_2 = pd.read_csv("/content/drive/MyDrive/hack_2023_11/data/manualmarkup.csv")

# %%
video_meta.sample(2)
# Out:
#                 video_id                                        video_title  \
# 9901479   video_12509079  Леонид Андреев, Виктор Таланов. Современная со...
# 21638683   video_2048243                               Видео родов кесарево
#
#                                               channel_title  \
# 9901479   Современная Cоционика * Socionics Archetype Ce...
# 21638683                           Искусство чернил и жизни
#
#             v_channel_reg_datetime v_channel_type v_category  \
# 9901479  2014-01-12 13:18:01+04:00            UGC  Лайфстайл
# 21638683 2023-11-02 16:24:28+03:00            UGC     Разное
#
#                     v_pub_datetime
# 9901479  2022-08-12 12:34:21+03:00
# 21638683 2023-11-03 19:06:10+03:00

# %%
queries_1.sample(2)
# Out:
#          is_authorized                   datetime                 query  \
# 3154816          False  2023-08-02 17:11:49+03:00         Выжить в дуба
# 1612238          False  2023-08-06 20:45:03+03:00  харламов батрутдинов
#
#               video_id  duration  position  watchtime  emotion  vtop  comment  \
# 3154816    video_97134   5512000       1.0       5663        0  None        0
# 1612238  video_7109004    609803      24.0        592        0  None        0
#
#                channel         tv_show season
# 3154816  Телеканал ТНТ  Выжить в Дубае   None
# 1612238    Comedy Club     Камеди Клаб   None

# %%
queries_2.sample(2)
# Out:
#                  query        video_id           query_date  sentiment
# 11080  пальма продакшн  video_10153963  2023-11-03 18:00:00  uselessly
# 606     надежда санько   video_8245346  2023-11-03 18:00:00  сlickbait

# %% [markdown]
# # Aggregate video attributes

# %%
video_meta = pd.DataFrame(video_meta[["video_title", "channel_title"]].unstack().rename("text")).reset_index(drop=True)

video_meta = video_meta[video_meta["text"].progress_apply(lambda x: WORD_PATTERN.search(x) is not None)] \
    .reset_index(drop=True)
# Out:
# 100%|██████████| 68809122/68809122 [01:50<00:00, 622505.65it/s]

# %%
video_meta["clean_text"] = video_meta["text"] \
    .progress_apply(
    lambda x: spell_checker.predict_single_correction(
        x, use_preprocessing=True, use_keyboard_inverter=False, use_correction=False
    ))

# %%
unigrams = defaultdict(int)
for idx, sublist in tqdm(enumerate(video_meta["clean_text"])):
    for word in sublist.split():
        if WORD_PATTERN.search(word) is not None:
            if word in VALID_CHARS:
                pass
            else:
                word = word.strip(WORD_STRIP)
            unigrams[word] = unigrams.get(word, 0) + 1
# Out:
# 32115348it [03:20, 159815.53it/s]

# %%
bigrams = defaultdict(int)
for sublist in tqdm(video_meta["clean_text"]):
    tokens = []
    for word in sublist.split():
        if WORD_PATTERN.search(word) is not None:
            if word in VALID_CHARS:
                tokens.append(word)
            else:
                tokens.append(word.strip(WORD_STRIP))
    for bigram in ngrams(tokens, 2):
        b = " ".join(bigram)
        bigrams[b] = bigrams.get(b, 0) + 1
# Out:
# 100%|██████████| 32115348/32115348 [08:36<00:00, 62135.00it/s]

# %%
min_unigram = int(spell_checker.config["SYMSPELL_PARAMS"]["MIN_UNIGRAM_COUNT"])
min_bigram = int(spell_checker.config["SYMSPELL_PARAMS"]["MIN_BIGRAM_COUNT"])

# %%
unigrams = {k: v if v >= min_unigram else min_unigram for k, v in unigrams.items()}
bigrams = {k: v if v >= min_bigram else min_bigram for k, v in bigrams.items()}

# %%
video_meta.to_parquet("data/clean_videos.parquet", index=False)

# %% [markdown]
# # Aggregate queries

# %%
queries = pd.DataFrame(pd.concat([queries_1["query"], queries_2["query"]]).rename("text"))

del queries_1, queries_2

# %%
queries = queries[queries["text"].progress_apply(lambda x: WORD_PATTERN.search(x) is not None)] \
    .reset_index(drop=True)
# Out:
# 100%|██████████| 6251664/6251664 [00:06<00:00, 975303.77it/s]

# %%
queries["clean_text"] = queries["text"] \
    .progress_apply(
    lambda x: spell_checker.predict_single_correction(
        x, use_preprocessing=True, use_keyboard_inverter=False, use_correction=False
    ))
# Out:
# 100%|██████████| 6104110/6104110 [02:05<00:00, 48790.20it/s]

# %%
q_unigrams = defaultdict(int)
for idx, sublist in tqdm(enumerate(queries["clean_text"])):
    for word in sublist.split():
        if WORD_PATTERN.search(word) is not None:
            if word in VALID_CHARS:
                pass
            else:
                word = word.strip(WORD_STRIP)
            q_unigrams[word] = q_unigrams.get(word, 0) + 1
# Out:
# 6104110it [00:17, 341650.52it/s]

# %%
q_bigrams = defaultdict(int)
for sublist in tqdm(queries["clean_text"]):
    tokens = []
    for word in sublist.split():
        if WORD_PATTERN.search(word) is not None:
            if word in VALID_CHARS:
                tokens.append(word)
            else:
                tokens.append(word.strip(WORD_STRIP))
    for bigram in ngrams(tokens, 2):
        b = " ".join(bigram)
        q_bigrams[b] = q_bigrams.get(b, 0) + 1
# Out:
# 100%|██████████| 6104110/6104110 [00:26<00:00, 227899.01it/s]

# %%
np.quantile(list(q_unigrams.values()), .75), np.quantile(list(q_unigrams.values()), .95), np.quantile(list(q_unigrams.values()), .99)
# Out:
# (3.0, 31.0, 321.0)

# %%
np.quantile(list(q_bigrams.values()), .75), np.quantile(list(q_bigrams.values()), .95), np.quantile(list(q_bigrams.values()), .99)
# Out:
# (2.0, 9.0, 62.0)

# %%
print([k for k, v in q_unigrams.items() if v > 321])
# Out:
# ['роман', 'битва', 'экстрасенсов', '2019', 'год', 'сильнейших', '2', 'сезон', 'bitva', 'silneyshix', 'sezon', 'экстросенсы', '10', 'выпуск', 'экстрасенсы', 'серия', '02', 'сильнейший', 'х', '2018', 'новая', 'сезо', 'александр', 'сез', '2сезон', '1', '2020', '20', 'за', 'с', 'сильнеших', '19', '12', '22', '6', 'старые', 'выпуски', '4', 'сильнейшие', '8', '18', 'битвы', 'экстрассенсов', '07', '3', '7', '2023', 'смотреть', '35', 'виктория', 'райдос', 'ведут', 'расследование', 'анонс', 'экстрасены', 'вып', '17', 'и', '23', '13', 'декабря', '2022', 'си', 'топ', 'бесплатно', 'самых', '11', '9', 'экстрасенсев', 'все', 'серии', 'подряд', 'comedy', 'woman', 'камеди', 'вумен', 'выжить', 'в', 'дубае', 'дубаи', 'часть', 'от', 'тнт', 'шоу', 'знаю', 'дубай', 'июля', 'черный', 'двор', 'звезды', 'вдубае', 'большое', 'версия', 'как', 'на', 'воля', 'каникулы', '1сезон', 'я', 'тебе', 'не', 'верю', 'выжившие', '2серия', '14', '01', 'однажды', 'пять', 'минут', 'тишины', '.', '2выпуск', 'дубаях', 'выжать', 'африке', 'выдить', 'а', 'думае', 'дуюае', 'пятница', 'вы', 'дуба', 'пропавшей', 'деревни', 'выжитьв', 'пустыне', 'выжыть', 'первый', 'подкаст', 'канале', 'о', 'будущее', 'ты', 'супер', 'рутуб', 'ру', 'новое', 'ds', 'bnm', 'd', 'le', 'v', 'dubae', 'dubai', 'ду', 'выживание', 'д', 'солдатки', 'премьера', '25', 'июня', 'выпус', 'ю', 'выжит', 'воли', 'наши', 'найти', 'олег', 'шепс', 'радио', 'кстати', '06', 'вижить', 'стас', 'сериал', 'манюня', 'жить', 'ляйсан', 'паша', 'дуб', 'вторая', 'онлайн', 'vijit', 'ы', 'павел', 'это', '29', 'января', 'сваты', 'последний', 'герой', 'же', 'реалити', 'юмор', 'тв', '03', 'дмитрий', 'дети', 'утяшева', 'жизнь', 'содержанки', 'стс', 'юность', 'две', '21', '05', 'году', 'галустян', 'балет', 'здравствуйте', 'вам', 'комедия', 'премьер', 'у', 'видео', 'музыкальная', 'интуиция', 'команды', 'прямой', 'эфир', 'сердце', 'ивлеевой', '5', 'фильм', 'тайна', 'сери', 'открытый', 'брак', 'остров', 'людей', 'фильмы', 'сериалы', 'е', 'про', '31', 'жена', 'против', 'центр', 'игра', 'бали', 'песни', 'африки', 'после', 'второй', 'измены', 'артем', 'из', 'full', 'больше', 'отпуск', 'шекер', 'дом', 'свежие', 'трудные', 'подростки', 'бывшие', 'новые', 'ивановы', 'хайп', 'б', 'два', 'холма', 'старт', 'остаться', 'ночь', 'агент', 'pdtpls', 'без', 'связи', 'сама', 'полностью', 'звезд', 'голосование', 'й', 'скачать', '09', 'путь', 'история', 'зведы', 'телеканал', 'заезды', 'т', 'давай', 'сер', 'вызов', 'dsgecr', 'эпизод', 'попробуй', 'reality', 'show', '15', 'cthbz', 'красиво', 'хорошем', 'качестве', '16', 'проект', 'почему', 'сюжет', 'игры', 'плейлист', 'live', 'in', 'обмен', 'звездыв', '5выпуск', 'смотри', 'еще', 'просто', 'так', 'снова', 'https', 'rutube', 'ru', '2-й', 'третий', 'три', 'кота', 'нового', 'hype', 'для', 'любви', 'се', 'но', 'концерты', 'лучшее', '26', '36', '28', 'звезда', 'sex', 'приключения', 'мама', 'что', 'он', 'м', 'ее', 'программа', 'передача', 'жизни', 'моя', 'мать', 'была', 'к', 'полный', '08', 'универ', 'лет', 'спустя', 'адский', 'честь', 'бузова', 'скандал', 'э', 'африка', 'пляже', 'истории', 'выпуска', 'зона', 'комфорта', 'online', 'обзор', 'секреты', 'сериала', 'кровь', 'финал', 'l', '1выпуск', 'африк', 'павла', 'встреча', 'musik', 'музыка', 'новинки', 'хиты', 'самые', 'лучшие', 'russische', 'клипы', 'русские', 'ноября', '24', '2024', 'года', 'сельнейших', 'итва', 'сильнйших', 'сильней', 'свои', 'экстрасенс', 'сил', 'юитва', 'битв', 'ekstrasensi', 'олегом', 'силь', 'сильн', '32', 'nбитва', 'последняя', 'екстрасенсы', 'там', 'было', 'самом', 'деле', 'сильнейши', 'мая', 'эксрасенсов', 'бит', '5серия', 'экстрассенсы', 'силнейших', 'новый', 'бритва', 'сильнейщих', 'девочка', 'родила', 'ьитва', 'где', 'саша', 'один', 'лучших', 'катя', 'силтнейших', 'стльнейших', 'эктрасенсы', 'сильейших', '04', 'бива', 'убийца', 'глаз', 'битвасильнейших', 'битве', 'рутубе', 'эксрасенсы', '1.', '46', 'последнее', 'экстросенсов', 'бтва', 'паши', 'спецвыпуск', '4сезон', 'эстрасенсы', 'экстра', 'бита', 'сезоны', 'экстасенсы', 'номер', ' ...

# %%
q_unigrams = {k: v if v >= min_unigram else 321 for k, v in q_unigrams.items()}
q_bigrams = {k: v if v >= min_bigram else 62 for k, v in q_bigrams.items()}

# %% [markdown]
# # Merge and collect final dicts

# %%
for k, v in q_unigrams.items():
    unigrams[k] = unigrams.get(k, 0) + v
del q_unigrams

for k, v in q_bigrams.items():
    bigrams[k] = bigrams.get(k, 0) + v
del q_bigrams

# %%
len(unigrams), len(bigrams)
# Out:
# (5420366, 52496323)

# %%
with open("spelling_checker/mount_files/symspell/ru.txt", "r", encoding="utf-8") as f:
    rus = f.readlines()

with open("spelling_checker/mount_files/symspell/en.txt", "r", encoding="utf-8") as f:
    eng = f.readlines()

# %%
rus = dict([i.strip().split() for i in rus])
eng = dict([i.strip().split() for i in eng])

# %%
vocab = defaultdict(int)

# %%
for k, v in unigrams.items():
    vocab[k] = int(rus.get(k, 0)) + int(eng.get(k, 0)) + v

# %%
filename = os.path.join("/content/drive/MyDrive/hack_2023_11/spelling_checker/mount_files/symspell", "unigrams.txt")

with open(filename, "w", encoding="utf-8") as f:
    for k, v in sorted(vocab.items(), key=lambda item: item[1], reverse=True):
        f.write(f"{k}${v}\n")

# %%
filename = os.path.join("/content/drive/MyDrive/hack_2023_11/spelling_checker/mount_files/symspell", "bigrams.txt")

with open(filename, "w", encoding="utf-8") as f:
    for k, v in sorted(bigrams.items(), key=lambda item: item[1], reverse=True):
        f.write(f"{k}${v}\n")
